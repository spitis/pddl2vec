# %% [markdown]
# # api.planning.domains Guide

# %% [markdown]
# The api contains many useful functions that tell us info about available domains, and different problem instances that are available for those domains (from past ICAPS competitions). Here are the most useful functions
#
# * `find_domains(name)` gets us a list of domains matching the name of the planning problem. There can be multiple entries from multiple competitions, and they might differ slightly
# * `get_domain(id)` allows us to see info regarding a particular domain with the specified id. Not really necessary if we call `find_domains(name)` first since that is like calling `get_domain(id)` for all relevant ids of that domain
# * `get_problems(did)` returns a list of problem objects (dictionaries) that have problem meta data regarding difficulty, and also have the urls of the domain and problem files

# %%
from planning_api_tools import planning_domains_api as api
import pprint
import wget
# Out:
#  Warning: No domain path is set

# %%
transport_domains = api.find_domains("transport")
pprint.pprint(transport_domains)
# Out:
# [{u'description': u'(opt11) Each vehicle can transport some packages depending on its capacity and moving has a cost depending on the length of the road. Picking up or dropping a package costs 1.',
#   u'domain_id': 13,
#   u'domain_name': u'transport',
#   u'tags': u'[":action-costs",":typing"]'},
#  {u'description': u'(opt14) Each vehicle can transport some packages depending on its capacity and moving has a cost depending on the length of the road. Picking up or dropping a package costs 1.',
#   u'domain_id': 11,
#   u'domain_name': u'transport',
#   u'tags': u'[":adl",":strips",":action-costs",":equality",":typing"]'},
#  {u'description': u'(sat08) Each vehicle can transport some packages depending on its capacity and moving has a cost depending on the length of the road. Picking up or dropping a package costs 1.',
#   u'domain_id': 51,
#   u'domain_name': u'transport',
#   u'tags': u'[":adl",":strips",":action-costs",":equality",":typing"]'},
#  {u'description': u'(sat14) Each vehicle can transport some packages depending on its capacity and moving has a cost depending on the length of the road. Picking up or dropping a package costs 1.',
#   u'domain_id': 118,
#   u'domain_name': u'transport',
#   u'tags': u'[":adl",":strips",":conditional-effects",":action-costs",":derived-predicates",":equality",":negative-preconditions",":typing"]'},
#  {u'description': u'(opt08) Each vehicle can transport some packages depending on its capacity and moving has a cost depending on the length of the road. Picking up or dropping a package costs 1.',
#   u'domain_id': 57,
#   u'domain_name': u'transport',
#   u'tags': u'[":adl",":strips",":conditional-effects",":action-costs",":derived-predicates",":equality",":negative-preconditions",":typing"]'},
#  {u'description': u'(sat11) Each vehicle can transport some packages depending on its capacity and moving has a cost depending on the length of the road. Picking up or dropping a package costs 1.',
#   u'domain_id': 6,
#   u'domain_name': u'transport',
#   u'tags': u'[":adl",":strips",":conditional-effects",":action-costs",":derived-predicates",":equality",":negative-preconditions",":typing"]'}]

# %% [markdown]
# Notice how the different domains have **(opt)** or **(sat)** in the description indicating if the goal is optimal or satisficing planning respectively. So one of the domains has id 11, let's try that one. `get_domain(id)` will get us a basic description of the domain like so

# %%
domain = api.get_domain(11)
domain
# Out:
# {u'description': u'(opt14) Each vehicle can transport some packages depending on its capacity and moving has a cost depending on the length of the road. Picking up or dropping a package costs 1.',
#  u'domain_id': 11,
#  u'domain_name': u'transport',
#  u'tags': u'[":adl",":strips",":action-costs",":equality",":typing"]'}

# %% [markdown]
# Now if we want to see some problems in this domain, we use `get_problems(id)`

# %%
problems = api.get_problems(11)
problems
# Out:
# [{u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 719,
#   u'lower_bound_description': u'haslum/pd-missing-hlb/condeff-compilation/719',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p19.pddl',
#   u'problem_id': 266,
#   u'problem_path': u'classical/transport-opt14-strips/p19.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p19.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 2138,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 719,
#   u'lower_bound_description': u'haslum/pd-missing-hlb/condeff-compilation/719',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p20.pddl',
#   u'problem_id': 267,
#   u'problem_path': u'classical/transport-opt14-strips/p20.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p20.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 2138,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 250,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(lmcut())',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p04.pddl',
#   u'problem_id': 251,
#   u'problem_path': u'classical/transport-opt14-strips/p04.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p04.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 250,
#   u'upper_bound_description': u'Validated plan submitted by: florian.pommerening@unibas.ch'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 1173,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(blind())',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p08.pddl',
#   u'problem_id': 255,
#   u'problem_path': u'classical/transport-opt14-strips/p08.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p08.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 1173,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 594,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(blind())',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p13.pddl',
#   u'problem_id': 260,
#   u'problem_path': u'classical/transport-opt14-strips/p13.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p13.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 594,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 370,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(lmcut())/explored f-layer',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p05.pddl',
#   u'problem_id': 252,
#   u'problem_path': u'classical/transport-opt14-strips/p05.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p05.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 744,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 684,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(lmcut())/explored f-layer',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p18.pddl',
#   u'problem_id': 265,
#   u'problem_path': u'classical/transport-opt14-strips/p18.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p18.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 1729,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 751,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(lmcut())/explored f-layer',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p10.pddl',
#   u'problem_id': 257,
#   u'problem_path': u'classical/transport-opt14-strips/p10.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p10.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 2316,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 366,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(lmcut())/explored f-layer',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p06.pddl',
#   u'problem_id': 253,
#   u'problem_path': u'classical/transport-opt14-strips/p06.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p06.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 744,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 710,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(lmcut())/explored f-layer',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p11.pddl',
#   u'problem_id': 258,
#   u'problem_path': u'classical/transport-opt14-strips/p11.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p11.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 1745,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 738,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(lmcut())/explored f-layer',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p12.pddl',
#   u'problem_id': 259,
#   u'problem_path': u'classical/transport-opt14-strips/p12.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p12.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 2816,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 630,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(lmcut())/explored f-layer',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p16.pddl',
#   u'problem_id': 263,
#   u'problem_path': u'classical/transport-opt14-strips/p16.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p16.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 1912,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 746,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(lmcut())/explored f-layer',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p09.pddl',
#   u'problem_id': 256,
#   u'problem_path': u'classical/transport-opt14-strips/p09.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p09.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 1375,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 526,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(blind())',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p14.pddl',
#   u'problem_id': 261,
#   u'problem_path': u'classical/transport-opt14-strips/p14.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p14.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 526,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 628,
#   u'lower_bound_description': u'haslum/pd-missing-hlb/condeff-compilation/628',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p17.pddl',
#   u'problem_id': 264,
#   u'problem_path': u'classical/transport-opt14-strips/p17.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p17.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 2102,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 300,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(blind())',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p03.pddl',
#   u'problem_id': 250,
#   u'problem_path': u'classical/transport-opt14-strips/p03.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p03.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 300,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 191,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(blind())',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p02.pddl',
#   u'problem_id': 249,
#   u'problem_path': u'classical/transport-opt14-strips/p02.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p02.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 191,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 967,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(blind())',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p07.pddl',
#   u'problem_id': 254,
#   u'problem_path': u'classical/transport-opt14-strips/p07.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p07.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 967,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 148,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(blind())',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p01.pddl',
#   u'problem_id': 248,
#   u'problem_path': u'classical/transport-opt14-strips/p01.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p01.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 148,
#   u'upper_bound_description': u'Resetting the upper bounds'},
#  {u'average_effective_width': None,
#   u'average_effective_width_description': u' ',
#   u'domain': u'transport',
#   u'domain_id': 11,
#   u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#   u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#   u'lower_bound': 753,
#   u'lower_bound_description': u'Pommerening/Fast Downward/08bff46b616b/astar(lmcut())',
#   u'max_effective_width': None,
#   u'max_effective_width_description': u' ',
#   u'problem': u'p15.pddl',
#   u'problem_id': 262,
#   u'problem_path': u'classical/transport-opt14-strips/p15.pddl',
#   u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p15.pddl',
#   u'tags': u'[]',
#   u'upper_bound': 753,
#   u'upper_bound_description': u'Validated plan submitted by: florian.pommerening@unibas.ch'}]

# %% [markdown]
# Let's look at a specific problem instance to make things more clean. Each problem has a problem pddl file path, as well as a domain path which is shared among many problem instances.

# %%
problem = problems[0]
problem
# Out:
# {u'average_effective_width': None,
#  u'average_effective_width_description': u' ',
#  u'domain': u'transport',
#  u'domain_id': 11,
#  u'domain_path': u'classical/transport-opt14-strips/domain.pddl',
#  u'domain_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/domain.pddl',
#  u'lower_bound': 719,
#  u'lower_bound_description': u'haslum/pd-missing-hlb/condeff-compilation/719',
#  u'max_effective_width': None,
#  u'max_effective_width_description': u' ',
#  u'problem': u'p19.pddl',
#  u'problem_id': 266,
#  u'problem_path': u'classical/transport-opt14-strips/p19.pddl',
#  u'problem_url': u'http://www.haz.ca/planning-domains/classical/transport-opt14-strips/p19.pddl',
#  u'tags': u'[]',
#  u'upper_bound': 2138,
#  u'upper_bound_description': u'Resetting the upper bounds'}

# %% [markdown]
# Now we can use wget to download the problem and domain files locally so we can run a planner on them

# %%
wget.download(problem["problem_url"])
# Out:
# u'p19 (1).pddl'
